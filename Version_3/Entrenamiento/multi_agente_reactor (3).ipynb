# %% [markdown]
# # REACTOR
#
# Proviene del caso de la notebook

# %% [markdown]
# ## 1. Imports

# %%
# !pip install torchinfo
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import random
import os

from typing import Dict, Any, List
import torch
import torch.nn as nn
from torchinfo import summary

import sys
sys.path.append('..')  # Subir un nivel para acceder a las carpetas

# Imports del proyecto
from Environment.simulation_env import SimulationPIDEnv # Ambiente de simulación PID
from Simulations_Env.reactor_CSTR import CSTRSimulator # Simulador de tanque simple
from Agent.DQN.algorithm_DQN import DQNAgent  # Agente DQN para control
from Agent.Actor_Critic.algorithm_ActorCritic import ActorCriticAgent
from Environment.multi_agent_env_modular import MultiAgentPIDEnv
from Entrenamiento.controller_agent import ControllerAgent

# Configuración de matplotlib
plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

print("✅ Imports completados")
print(f"PyTorch version: {torch.__version__}")
print(f"Device disponible: {'cuda' if torch.cuda.is_available() else 'cpu'}")
# Out:
# ✅ Imports completados
# PyTorch version: 2.8.0+cu126
# Device disponible: cuda

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Nov 19 19:53:56 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             46W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
torch.zeros(1).cuda()

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Running on {DEVICE}")

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.backends.cudnn.deterministic = True

print("Cuda Available:", torch.cuda.is_available())
# Out:
# Running on cuda:0
# Cuda Available: True

# %% [markdown]
# ## W&B

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.22.3)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.44.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)

# %%
import wandb
import os

# Deshabilitar hooks de Jupyter para evitar AlreadyJoinedError
os.environ["WANDB_NOTEBOOK_NAME"] = "multi_agente_reactor"
os.environ["WANDB_SILENT"] = "true"

# Login
wandb.login()

# Desregistrar hooks de Jupyter que causan AlreadyJoinedError
try:
    from IPython import get_ipython
    ipython = get_ipython()
    if ipython is not None:
        # Remover callbacks de wandb si existen
        callbacks = ipython.events.callbacks
        for event in ['pre_run_cell', 'post_run_cell']:
            if event in callbacks:
                # Filtrar callbacks de wandb
                callbacks[event] = [cb for cb in callbacks[event] 
                                   if 'wandb' not in str(cb).lower()]
        print("✅ Hooks de Jupyter de WandB deshabilitados")
except Exception as e:
    print(f"⚠️ No se pudieron deshabilitar hooks: {e}")
    pass

# %%
WANDB_TEAM_NAME = "valeriaeskenazi-universidad-ort-uruguay"
WANDB_PROJECT = "Tesis_maestría"

sweep_config = {
    "name": "multi_agent_reactor_cstr",
    "method": "random",

    "metric": {
        "name": "global_reward",  # Recompensa del orquestador
        "goal": "maximize"
    },

    "parameters": {
        "mode": {
            "value": "indirect"
        },

        # ========== CONTROLADORES (DQN) ==========
        "controller_hidden_dims": {
            "values": [
                [64, 64],
                [128, 128, 64]
            ]
        },

        "controller_lr": {
            "values": [0.0001, 0.001]
        },

        "controller_gamma": {
            "values": [0.99, 0.999]
        },

        # ========== ORQUESTADOR (Actor-Critic) ==========
        "orch_hidden_dims": {
            "values": [
                [64, 64],
                [128, 128, 64]
            ]
        },

        "orch_lr_actor": {
            "values": [0.00001, 0.0001]
        },

        "orch_lr_critic": {
            "values": [0.0001, 0.001]
        },

        "orch_gamma": {
            "values": [0.99, 0.999]
        },

        # ========== ENTRENAMIENTO ==========
        "n_episodes": {
            "values": [5, 10]
        },

        "j_max_retries": {
            "values": [3, 5]
        },

        "r_orchestrator_iterations": {
            "values": [10, 20]
        },

        # ========== REACTOR ==========
        "n_manipulable_vars": {
            "value": 2  # Flujo y Temp
        },

        "n_target_vars": {
            "value": 1  # CB
        },

        "dead_band": {
            "values": [0.01, 0.02]
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project=WANDB_PROJECT)
# Out:
# Create sweep with ID: p6j3rtu4
# Sweep URL: https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4

# %%
def wandb_log_callback(iteration, global_reward, best_sp, pids, errors, stats=None):
    log_dict = {
        "iteration": iteration,
        "global_reward": global_reward,

        # Setpoints y PVs (para graficar SP vs PV)
        "sp_tc": best_sp[0],
        "sp_f": best_sp[1],

        # PIDs
        "controller_0_Kp": pids[0][0],
        "controller_0_Ki": pids[0][1],
        "controller_0_Kd": pids[0][2],
        "controller_1_Kp": pids[1][0],
        "controller_1_Ki": pids[1][1],
        "controller_1_Kd": pids[1][2],

        # Errores
        "controller_0_error": errors[0],
        "controller_1_error": errors[1],
        "avg_error": sum(errors) / len(errors)
    }

    # DATOS PARA GRÁFICOS
    if stats and 'current_pvs' in stats:
        log_dict["pv_tc"] = stats['current_pvs'][0]
        log_dict["pv_f"] = stats['current_pvs'][1]

    if stats and 'target_pv' in stats:
        log_dict["cb_actual"] = stats['target_pv']
        log_dict["cb_target"] = stats.get('target_sp', 0.2)

    wandb.log(log_dict)

# %%
def sweep_run():
    """
    Función que se ejecutará en cada run del sweep.
    """
    
    run = None
    try:
        # Configuración robusta de WandB para evitar errores de threading
        run = wandb.init(
            reinit=True,
            settings=wandb.Settings(
                start_method="thread",
                _disable_stats=True,
                _disable_meta=True,
            )
        )
        
        os.makedirs('results', exist_ok=True)
        os.makedirs('models', exist_ok=True)

        # ========== REPRODUCIBILIDAD ==========
        SEED = 42
        random.seed(SEED)
        np.random.seed(SEED)
        torch.manual_seed(SEED)
        if torch.cuda.is_available():
            torch.cuda.manual_seed(SEED)
            torch.backends.cudnn.deterministic = True
            torch.backends.cudnn.benchmark = False

        wandb.config.update({"seed": SEED}, allow_val_change=True)

        # ========== LEER CONFIGURACIÓN ==========
        config = wandb.config

        # ========== CONFIGURAR AMBIENTE MULTI-AGENTE ==========
        env_config = {
            'mode': 'indirect',
            'n_manipulable_vars': 2,
            'n_variables': 2,
            'n_target_vars': 1,
            'target_ranges': [(0.0, 1.0)],
            'target_setpoints': [0.2],
            'sp_ranges': [(290.0, 450.0), (99.0, 105.0)],
            'n_episodes': config.n_episodes,
            'j_max_retries': config.j_max_retries,
            'r_orchestrator_iterations': config.r_orchestrator_iterations,
            'upper_range': [450.0, 105.0],
            'lower_range': [290.0, 99.0],
            'setpoint': [370.0, 102.0],
            'dead_band': [config.dead_band, config.dead_band],
            'dt': 1.0,
            'max_episode_steps': 200,
            'agent_lr': config.controller_lr,
            'agent_gamma': config.controller_gamma,
            'epsilon_start': 1.0,
            'epsilon_min': 0.01,
            'epsilon_decay': 0.995,
            'hidden_dims': tuple(config.controller_hidden_dims),
            'initial_pid': (1.0, 0.1, 0.05),
            'orch_lr_actor': config.orch_lr_actor,
            'orch_lr_critic': config.orch_lr_critic,
            'orch_gamma': config.orch_gamma,
            'device': 'cpu',
            'wandb_log_callback': wandb_log_callback
        }

        # ========== CREAR AMBIENTE ==========
        multi_env = MultiAgentPIDEnv(env_config)
        reactor = CSTRSimulator(dt=1.0, control_limits=((290, 450), (99, 105)))
        multi_env.base_env.connect_external_process(reactor)

        # ========== ENTRENAR ==========
        best_pids, best_setpoints = multi_env.train()

        # ========== EVALUAR ==========
        global_reward = multi_env._execute_with_pids(best_pids, best_setpoints)

        # ========== GRÁFICOS CON ORQUESTADOR ACTIVO ==========
        # Resetear proceso externo y ambiente
        multi_env.base_env.reset_process()
        multi_env.base_env.reset()
        
        # Configurar PIDs optimizados
        for i in range(2):
            multi_env.base_env.pid_controllers[i].update_gains(
                kp=best_pids[i][0],
                ki=best_pids[i][1],
                kd=best_pids[i][2]
            )

        pvs_tc, pvs_f, cb_values = [], [], []
        sps_tc, sps_f = [], []
        errors_tc, errors_f, errors_orch = [], [], []
        actions_tc, actions_f = [], []

        for step in range(multi_env.max_episode_steps):
            # Obtener CB actual del reactor
            reactor_state = multi_env.base_env.external_process.get_state()
            cb_current = reactor_state[0]  # Cb está en índice 0
            
            # Orquestador decide nuevos setpoints basándose en CB actual
            new_setpoints = multi_env.orchestrator.decide_setpoints(
                pv_targets=[cb_current],
                sp_targets=[0.2]  # Target deseado para CB
            )
            
            # Aplicar nuevos setpoints al ambiente
            multi_env.base_env.set_setpoint(new_setpoints[0], var_idx=0)  # Tc
            multi_env.base_env.set_setpoint(new_setpoints[1], var_idx=1)  # F
            
            # Obtener estado del base_env
            state = multi_env.base_env._get_observation()

            # Controladores DQN seleccionan acciones para alcanzar los nuevos setpoints
            state_tc = state[0:6]
            state_f = state[6:12]
            action_tc = multi_env.controller_agents[0].dqn_agent.select_action(state_tc, training=False)
            action_f = multi_env.controller_agents[1].dqn_agent.select_action(state_f, training=False)

            actions_tc.append(action_tc)
            actions_f.append(action_f)

            # Ejecutar step con las acciones calculadas por los agentes
            state, _, done, _, info = multi_env.base_env.step([action_tc, action_f])

            # Guardar valores DESPUÉS del step
            pvs_tc.append(info['current_pvs'][0])
            pvs_f.append(info['current_pvs'][1])
            sps_tc.append(new_setpoints[0])  # Setpoints dinámicos del orquestador
            sps_f.append(new_setpoints[1])   # Setpoints dinámicos del orquestador
            
            # Actualizar CB después del step
            reactor_state = multi_env.base_env.external_process.get_state()
            cb_current = reactor_state[0]
            cb_values.append(cb_current)

            # Calcular errores
            errors_tc.append(new_setpoints[0] - info['current_pvs'][0])
            errors_f.append(new_setpoints[1] - info['current_pvs'][1])
            errors_orch.append(0.2 - cb_current)

            if done:
                break

        # Agregar debug para ver si hay datos
        print(f"📊 Datos recolectados:")
        print(f"   PVs TC: {len(pvs_tc)} puntos, rango: [{min(pvs_tc) if pvs_tc else 'N/A'}, {max(pvs_tc) if pvs_tc else 'N/A'}]")
        print(f"   SPs TC: {len(sps_tc)} puntos, rango: [{min(sps_tc) if sps_tc else 'N/A'}, {max(sps_tc) if sps_tc else 'N/A'}]")
        print(f"   PVs F: {len(pvs_f)} puntos, rango: [{min(pvs_f) if pvs_f else 'N/A'}, {max(pvs_f) if pvs_f else 'N/A'}]")
        print(f"   SPs F: {len(sps_f)} puntos, rango: [{min(sps_f) if sps_f else 'N/A'}, {max(sps_f) if sps_f else 'N/A'}]")
        print(f"   CB: {len(cb_values)} puntos, rango: [{min(cb_values) if cb_values else 'N/A'}, {max(cb_values) if cb_values else 'N/A'}]")

        # Crear figura con 8 subplots
        fig = plt.figure(figsize=(16, 20))
        gs = fig.add_gridspec(4, 2, hspace=0.3, wspace=0.3)

        # Fila 1: PV vs SP (con setpoints dinámicos)
        ax1 = fig.add_subplot(gs[0, 0])
        ax1.plot(pvs_tc, label='PV Tc', linewidth=2)
        ax1.plot(sps_tc, '--', label='SP Tc', linewidth=2, alpha=0.7)
        ax1.set_xlabel('Pasos de simulación')
        ax1.set_ylabel('Temperatura (K)')
        ax1.set_title('Controlador Tc: PV vs SP')
        ax1.legend()
        ax1.grid(True, alpha=0.3)

        ax2 = fig.add_subplot(gs[0, 1])
        ax2.plot(pvs_f, label='PV F', linewidth=2)
        ax2.plot(sps_f, '--', label='SP F', linewidth=2, alpha=0.7)
        ax2.set_xlabel('Pasos de simulación')
        ax2.set_ylabel('Flujo (m³/s)')
        ax2.set_title('Controlador F: PV vs SP')
        ax2.legend()
        ax2.grid(True, alpha=0.3)

        # Fila 2: CB con deadband
        ax3 = fig.add_subplot(gs[1, :])
        ax3.plot(cb_values, label='CB actual', linewidth=2)
        ax3.axhline(0.2, color='r', linestyle='--', label='Target')
        ax3.fill_between(range(len(cb_values)), 0.19, 0.21, alpha=0.2, color='orange', label='Deadband')
        ax3.set_xlabel('Pasos de simulación')
        ax3.set_ylabel('Concentración CB')
        ax3.set_title('Orquestador: CB vs Target')
        ax3.legend()
        ax3.grid(True, alpha=0.3)

        # Fila 3: Errores
        ax4 = fig.add_subplot(gs[2, 0])
        ax4.plot(errors_tc, linewidth=2, color='red')
        ax4.set_xlabel('Pasos de simulación')
        ax4.set_ylabel('Error Tc')
        ax4.set_title('Error Controlador Tc')
        ax4.axhline(0, color='black', linestyle='--', alpha=0.3)
        ax4.grid(True, alpha=0.3)

        ax5 = fig.add_subplot(gs[2, 1])
        ax5.plot(errors_f, linewidth=2, color='red')
        ax5.set_xlabel('Pasos de simulación')
        ax5.set_ylabel('Error F')
        ax5.set_title('Error Controlador F')
        ax5.axhline(0, color='black', linestyle='--', alpha=0.3)
        ax5.grid(True, alpha=0.3)

        # Fila 4: Histogramas de acciones
        ax6 = fig.add_subplot(gs[3, 0])
        ax6.hist(actions_tc, bins=7, range=(-0.5, 6.5), edgecolor='black')
        ax6.set_xlabel('Acción')
        ax6.set_ylabel('Frecuencia')
        ax6.set_title('Distribución Acciones DQN - Tc')
        ax6.set_xticks(range(7))
        ax6.grid(True, alpha=0.3)

        ax7 = fig.add_subplot(gs[3, 1])
        ax7.hist(actions_f, bins=7, range=(-0.5, 6.5), edgecolor='black')
        ax7.set_xlabel('Acción')
        ax7.set_ylabel('Frecuencia')
        ax7.set_title('Distribución Acciones DQN - F')
        ax7.set_xticks(range(7))
        ax7.grid(True, alpha=0.3)

        # Agregar error del orquestador como texto
        fig.text(0.5, 0.02, f'Error promedio orquestador (CB): {np.mean(np.abs(errors_orch)):.4f}',
                ha='center', fontsize=12, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

        # Subir a W&B
        wandb.log({"evaluation_plots": wandb.Image(fig)})
        plt.close()

        # ========== LOGUEAR MÉTRICAS FINALES ==========
        stats = multi_env.get_statistics()
        wandb.log({
            'global_reward': global_reward,
            'best_sp_tc': best_setpoints[0],
            'best_sp_f': best_setpoints[1],
            'controller_0_Kp': best_pids[0][0],
            'controller_0_Ki': best_pids[0][1],
            'controller_0_Kd': best_pids[0][2],
            'controller_1_Kp': best_pids[1][0],
            'controller_1_Ki': best_pids[1][1],
            'controller_1_Kd': best_pids[1][2],
            'success_rate': stats['pid_trainer']['success_rate'],
            'avg_best_error': stats['pid_trainer']['avg_best_error']
        })

        print(f"\n✅ Run completado: {wandb.run.name}")
        print(f"   Global reward: {global_reward:.2f}")
        print(f"   Best SP: Tc={best_setpoints[0]:.2f}, F={best_setpoints[1]:.2f}")

    except Exception as e:
        print(f"❌ Error durante el run: {str(e)}")
        import traceback
        traceback.print_exc()
        if run is not None:
            try:
                wandb.log({"error": str(e)})
            except:
                pass
    
    finally:
        # Asegurar que wandb se cierra correctamente
        if run is not None:
            try:
                wandb.finish(quiet=True, exit_code=0)
            except Exception as e:
                print(f"⚠️ Warning al cerrar WandB (ignorado): {e}")
                pass

# %%
wandb.agent(sweep_id, function=sweep_run, count=2)
# Out:
# wandb: Agent Starting Run: 0l76udqq with config:
# wandb: 	controller_gamma: 0.999
# wandb: 	controller_hidden_dims: [128, 128, 64]
# wandb: 	controller_lr: 0.0001
# wandb: 	dead_band: 0.02
# wandb: 	j_max_retries: 3
# wandb: 	mode: indirect
# wandb: 	n_episodes: 10
# wandb: 	n_manipulable_vars: 2
# wandb: 	n_target_vars: 1
# wandb: 	orch_gamma: 0.99
# wandb: 	orch_hidden_dims: [128, 128, 64]
# wandb: 	orch_lr_actor: 1e-05
# wandb: 	orch_lr_critic: 0.0001
# wandb: 	r_orchestrator_iterations: 20
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251119_195450-0l76udqq</code>
# Syncing run <strong><a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/0l76udqq' target="_blank">mild-sweep-1</a></strong> to <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4</a>
#  View project at <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa</a>
#  View sweep at <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4</a>
#  View run at <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/0l76udqq' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/0l76udqq</a>
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Configurado como MULTI-AGENT (2 variables)
# ============================================================
# ✅ Modo: PID Tuning (Simulación)
#    N Variables: 2
#    Acciones por variable: 7
#    Espacio: MultiDiscrete([7, 7, ..., 7]) x2
#    PID inicial: (np.float32(1.0), np.float32(0.1), np.float32(0.05))
#    PIDControllers: 2 activos
# ============================================================
# ============================================================
# Actor-Critic Agent creado
#    Estado: 2 dims
#    Acciones: 2 dims (continuas)
#    Hidden layers: (128, 128, 64)
#    LR Actor: 1e-05
#    LR Critic: 0.0001
#    Gamma: 0.99
#    Device: cpu
# ============================================================
# ✅ OrchestratorAgent creado
#    Variables manipulables: 2
#    Rangos SP: [(290.0, 450.0), (99.0, 105.0)]
# ============================================================
# ✅ DQN Agent creado
#    Estado: 6 dims
#    Acciones: 7 (DeltaPIDActionSpace)
#    Hidden layers: (128, 128, 64)
#    Learning rate: 0.0001
#    Gamma: 0.999
#    Epsilon: 1.0 → 0.01 (decay: 0.995)
#    Device: cpu
# ============================================================
# ============================================================
# ✅ DQN Agent creado
#    Estado: 6 dims
#    Acciones: 7 (DeltaPIDActionSpace)
#    Hidden layers: (128, 128, 64)
#    Learning rate: 0.0001
#    Gamma: 0.999
#    Epsilon: 1.0 → 0.01 (decay: 0.995)
#    Device: cpu
# ============================================================
# ============================================================
# MultiAgentPIDEnv inicializado
# Arquitectura: indirect
# Variables manipulables: 2
# Base_env control_mode: pid_tuning
# ============================================================
# ============================================================
# ⚗️  Simulador de Reactor CSTR creado
#    Temperatura alimentación: 350.0 K
#    Concentración alimentación: 1.0 mol/m³
#    Límites Tc: [290, 450] K
#    Límites F: [99, 105] m³/s
#    Paso de tiempo: 1.0 s
#    Modo: Multi-variable (2 variables manipulables)
# ============================================================
# ✅ Proceso simulado conectado (2 variable(s))
# 🔧 Entrenando controlador 0 con SP=401.74468994140625
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(2.0747659e-21)), error=37.713470458984375
# 🔧 Entrenando controlador 1 con SP=102.37798309326172
#    Resultado: PID=(np.float32(1.082085), np.float32(2.1065326), np.float32(6.129991e-08)), error=37.71281814575195
#       Orquestador actualizado: actor_loss=0.2027, critic_loss=0.0215
# 🔧 Entrenando controlador 0 con SP=407.3427734375
#    Resultado: PID=(np.float32(1.2), np.float32(0.080000006), np.float32(4.0522766e-21)), error=37.715423583984375
# 🔧 Entrenando controlador 1 con SP=102.96900177001953
#    Resultado: PID=(np.float32(0.8), np.float32(0.1), np.float32(0.040000003)), error=37.708805084228516
#       Orquestador actualizado: actor_loss=0.2635, critic_loss=0.0277
# 🔧 Entrenando controlador 0 con SP=401.18841552734375
#    Resultado: PID=(np.float32(0.64000005), np.float32(0.120000005), np.float32(4.0522766e-21)), error=37.70741271972656
# 🔧 Entrenando controlador 1 con SP=102.69857025146484
#    Resultado: PID=(np.float32(1.0), np.float32(0.080000006), np.float32(0.05)), error=37.71238708496094
#       Orquestador actualizado: actor_loss=0.3707, critic_loss=0.0234
# 🔧 Entrenando controlador 0 con SP=387.9207763671875
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(2.0747659e-21)), error=37.70607376098633
# 🔧 Entrenando controlador 1 con SP=102.56690216064453
#    Resultado: PID=(np.float32(1.2), np.float32(0.09600001), np.float32(0.060000002)), error=37.712608337402344
#       Orquestador actualizado: actor_loss=0.2799, critic_loss=0.0207
# 🔧 Entrenando controlador 0 con SP=383.862060546875
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(2.0747659e-21)), error=37.709625244140625
# 🔧 Entrenando controlador 1 con SP=102.97248077392578
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.048000004)), error=37.71782302856445
#       Orquestador actualizado: actor_loss=0.2748, critic_loss=0.0284
# 🔧 Entrenando controlador 0 con SP=389.7474365234375
#    Resultado: PID=(np.float32(0.8), np.float32(0.11520001), np.float32(7.598018e-21)), error=37.716156005859375
# 🔧 Entrenando controlador 1 con SP=102.86207580566406
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.05)), error=37.70989227294922
#       Orquestador actualizado: actor_loss=0.4029, critic_loss=0.0256
# 🔧 Entrenando controlador 0 con SP=392.7287292480469
#    Resultado: PID=(np.float32(1.0), np.float32(0.064), np.float32(4.0522766e-21)), error=37.708778381347656
# 🔧 Entrenando controlador 1 con SP=102.9751968383789
#    Resultado: PID=(np.float32(1.1520001), np.float32(0.1), np.float32(0.05)), error=37.705081939697266
#       Orquestador actualizado: actor_loss=0.4310, critic_loss=0.0274
# 🔧 Entrenando controlador 0 con SP=403.7852783203125
#    Resultado: PID=(np.float32(0.8), np.float32(0.080000006), np.float32(9.1176225e-21)), error=37.704811096191406
# 🔧 Entrenando controlador 1 con SP=102.21175384521484
#    Resultado: PID=(np.float32(1.2), np.float32(0.1), np.float32(0.05)), error=37.70103454589844
#       Orquestador actualizado: actor_loss=0.0064, critic_loss=0.0171
# 🔧 Entrenando controlador 0 con SP=393.1012268066406
#    Resultado: PID=(np.float32(1.2), np.float32(0.0768), np.float32(6.331682e-21)), error=37.712921142578125
# 🔧 Entrenando controlador 1 con SP=102.85829162597656
#    Resultado: PID=(np.float32(1.0), np.float32(0.080000006), np.float32(0.05)), error=37.71015167236328
#       Orquestador actualizado: actor_loss=0.4347, critic_loss=0.0255
# 🔧 Entrenando controlador 0 con SP=390.027587890625
#    Resultado: PID=(np.float32(1.0), np.float32(0.080000006), np.float32(2.5934572e-21)), error=37.711605072021484
# 🔧 Entrenando controlador 1 con SP=102.9461441040039
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.040000003)), error=37.711116790771484
#       Orquestador actualizado: actor_loss=0.3943, critic_loss=0.0255
# 🔧 Entrenando controlador 0 con SP=404.4266052246094
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(3.112149e-21)), error=37.71367263793945
# 🔧 Entrenando controlador 1 con SP=102.42589569091797
#    Resultado: PID=(np.float32(1.0), np.float32(0.080000006), np.float32(0.040000003)), error=37.7065315246582
#       Orquestador actualizado: actor_loss=0.1639, critic_loss=0.0186
# 🔧 Entrenando controlador 0 con SP=398.942626953125
#    Resultado: PID=(np.float32(1.0), np.float32(0.064), np.float32(3.2418214e-21)), error=37.70820236206055
# 🔧 Entrenando controlador 1 con SP=102.74513244628906
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.05)), error=37.70903778076172
#       Orquestador actualizado: actor_loss=0.3952, critic_loss=0.0226
# 🔧 Entrenando controlador 0 con SP=394.5676574707031
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(3.1121485e-21)), error=37.70633316040039
# 🔧 Entrenando controlador 1 con SP=102.65804290771484
#    Resultado: PID=(np.float32(1.2), np.float32(0.1), np.float32(0.05)), error=37.71247482299805
#       Orquestador actualizado: actor_loss=0.3790, critic_loss=0.0218
# 🔧 Entrenando controlador 0 con SP=397.6441955566406
#    Resultado: PID=(np.float32(1.0), np.float32(0.120000005), np.float32(2.5934572e-21)), error=37.709632873535156
# 🔧 Entrenando controlador 1 con SP=103.20745849609375
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.040000003)), error=37.709049224853516
#       Orquestador actualizado: actor_loss=0.3584, critic_loss=0.0319
# 🔧 Entrenando controlador 0 con SP=403.1919860839844
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(2.0747659e-21)), error=37.70940399169922
# 🔧 Entrenando controlador 1 con SP=102.29695129394531
#    Resultado: PID=(np.float32(1.0), np.float32(0.09600001), np.float32(0.060000002)), error=37.712825775146484
#       Orquestador actualizado: actor_loss=0.0918, critic_loss=0.0199
# 🔧 Entrenando controlador 0 con SP=393.6225891113281
#    Resultado: PID=(np.float32(0.512), np.float32(0.1), np.float32(6.0784168e-21)), error=37.70807647705078
# 🔧 Entrenando controlador 1 con SP=103.07200622558594
#    Resultado: PID=(np.float32(0.8), np.float32(0.14400001), np.float32(0.05)), error=37.7179069519043
#       Orquestador actualizado: actor_loss=0.4461, critic_loss=0.0330
# 🔧 Entrenando controlador 0 con SP=402.32550048828125
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(2.5934572e-21)), error=37.707847595214844
# 🔧 Entrenando controlador 1 con SP=103.2130126953125
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.05)), error=37.703712463378906
#       Orquestador actualizado: actor_loss=0.3003, critic_loss=0.0318
# 🔧 Entrenando controlador 0 con SP=396.5644836425781
#    Resultado: PID=(np.float32(1.2), np.float32(0.080000006), np.float32(3.2418214e-21)), error=37.70705032348633
# 🔧 Entrenando controlador 1 con SP=103.0152587890625
#    Resultado: PID=(np.float32(1.0), np.float32(0.115200005), np.float32(0.05)), error=37.716854095458984
#       Orquestador actualizado: actor_loss=0.4492, critic_loss=0.0297
# 🔧 Entrenando controlador 0 con SP=396.5028381347656
#    Resultado: PID=(np.float32(0.8), np.float32(0.1), np.float32(2.5934572e-21)), error=37.71591567993164
# 🔧 Entrenando controlador 1 con SP=102.70716094970703
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.060000002)), error=37.70844650268555
#       Orquestador actualizado: actor_loss=0.3973, critic_loss=0.0224
# 🔧 Entrenando controlador 0 con SP=404.99945068359375
#    Resultado: PID=(np.float32(0.8), np.float32(0.1), np.float32(2.5934572e-21)), error=37.71223449707031
# 🔧 Entrenando controlador 1 con SP=103.10867309570312
#    Resultado: PID=(np.float32(1.0), np.float32(0.1), np.float32(0.05)), error=37.708866119384766
#       Orquestador actualizado: actor_loss=0.2804, critic_loss=0.0270
#
#  Run completado: mild-sweep-1
#    Global reward: -0.17
#    Best SP: Tc=403.79, F=102.21
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_best_error</td><td>▁</td></tr><tr><td>avg_error</td><td>█▇▆▅██▄▁▇▆▆▅▅▅▆█▃▇▇▆</td></tr><tr><td>best_sp_f</td><td>▁</td></tr><tr><td>best_sp_tc</td><td>▁</td></tr><tr><td>cb_actual</td><td>▂▆▄▃▆▆▆▁▆▆▂▅▄█▂▇█▇▄▇</td></tr><tr><td>cb_target</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>controller_0_Kd</td><td>▁▃▃▁▁▆▃█▅▂▂▂▂▂▁▅▂▂▂▂█</td></tr><tr><td>controller_0_Ki</td><td>▅▃█▅▅▇▁▃▃▃▅▁▅█▅▅▅▃▅▅▃</td></tr><tr><td>controller_0_Kp</td><td>▆█▂▆▆▄▆▄█▆▆▆▆▆▆▁▆█▄▄▄</td></tr><tr><td>controller_0_error</td><td>▆█▃▂▄█▃▁▆▅▆▃▂▄▄▃▃▂█▆</td></tr><tr><td>+11</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_best_error</td><td>37.7103</td></tr><tr><td>avg_error</td><td>37.71055</td></tr><tr><td>best_sp_f</td><td>102.21175</td></tr><tr><td>best_sp_tc</td><td>403.78528</td></tr><tr><td>cb_actual</td><td>0.66832</td></tr><tr><td>cb_target</td><td>0.2</td></tr><tr><td>controller_0_Kd</td><td>0.0</td></tr><tr><td>controller_0_Ki</td><td>0.08</td></tr><tr><td>controller_0_Kp</td><td>0.8</td></tr><tr><td>controller_0_error</td><td>37.71223</td></tr><tr><td>+11</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mild-sweep-1</strong> at: <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/0l76udqq' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/0l76udqq</a><br> View project at: <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251119_195450-0l76udqq/logs</code>
# wandb: Agent Starting Run: zemuurg6 with config:
# wandb: 	controller_gamma: 0.99
# wandb: 	controller_hidden_dims: [128, 128, 64]
# wandb: 	controller_lr: 0.001
# wandb: 	dead_band: 0.01
# wandb: 	j_max_retries: 3
# wandb: 	mode: indirect
# wandb: 	n_episodes: 5
# wandb: 	n_manipulable_vars: 2
# wandb: 	n_target_vars: 1
# wandb: 	orch_gamma: 0.999
# wandb: 	orch_hidden_dims: [64, 64]
# wandb: 	orch_lr_actor: 0.0001
# wandb: 	orch_lr_critic: 0.001
# wandb: 	r_orchestrator_iterations: 10
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251119_202750-zemuurg6</code>
# Syncing run <strong><a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/zemuurg6' target="_blank">still-sweep-2</a></strong> to <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4</a>
#  View project at <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa</a>
#  View sweep at <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/sweeps/p6j3rtu4</a>
#  View run at <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/zemuurg6' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/zemuurg6</a>
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.12/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Configurado como MULTI-AGENT (2 variables)
# ============================================================
# ✅ Modo: PID Tuning (Simulación)
#    N Variables: 2
#    Acciones por variable: 7
#    Espacio: MultiDiscrete([7, 7, ..., 7]) x2
#    PID inicial: (np.float32(1.0), np.float32(0.1), np.float32(0.05))
#    PIDControllers: 2 activos
# ============================================================
# ============================================================
# Actor-Critic Agent creado
#    Estado: 2 dims
#    Acciones: 2 dims (continuas)
#    Hidden layers: (128, 128, 64)
#    LR Actor: 0.0001
#    LR Critic: 0.001
#    Gamma: 0.999
#    Device: cpu
# ============================================================
# ✅ OrchestratorAgent creado
#    Variables manipulables: 2
#    Rangos SP: [(290.0, 450.0), (99.0, 105.0)]
# ============================================================
# ✅ DQN Agent creado
#    Estado: 6 dims
#    Acciones: 7 (DeltaPIDActionSpace)
#    Hidden layers: (128, 128, 64)
#    Learning rate: 0.001
#    Gamma: 0.99
#    Epsilon: 1.0 → 0.01 (decay: 0.995)
#    Device: cpu
# ============================================================
# ============================================================
# ✅ DQN Agent creado
#    Estado: 6 dims
#    Acciones: 7 (DeltaPIDActionSpace)
#    Hidden layers: (128, 128, 64)
#    Learning rate: 0.001
#    Gamma: 0.99
#    Epsilon: 1.0 → 0.01 (decay: 0.995)
#    Device: cpu
# ============================================================
# ============================================================
# MultiAgentPIDEnv inicializado
# Arquitectura: indirect
# Variables manipulables: 2
# Base_env control_mode: pid_tuning
# ============================================================
# ============================================================
# ⚗️  Simulador de Reactor CSTR creado
#    Temperatura alimentación: 350.0 K
#    Concentración alimentación: 1.0 mol/m³
#    Límites Tc: [290, 450] K
#    Límites F: [99, 105] m³/s
#    Paso de tiempo: 1.0 s
#    Modo: Multi-variable (2 variables manipulables)
# ============================================================
# ✅ Proceso simulado conectado (2 variable(s))
# 🔧 Entrenando controlador 0 con SP=401.74468994140625
#    Resultado: PID=(np.float32(0.5882018), np.float32(0.0072557563), np.float32(0.549756)), error=37.71174240112305
# 🔧 Entrenando controlador 1 con SP=102.37798309326172
#    Resultado: PID=(np.float32(0.017915443), np.float32(0.016958907), np.float32(0.024441002)), error=37.698814392089844
#       Orquestador actualizado: actor_loss=0.2141, critic_loss=0.0240
# 🔧 Entrenando controlador 0 con SP=406.8800048828125
#    Resultado: PID=(np.float32(0.33214214), np.float32(0.026070395), np.float32(1.0794358)), error=37.704952239990234
# 🔧 Entrenando controlador 1 con SP=103.01605987548828
#    Resultado: PID=(np.float32(2.5777617), np.float32(1.1513978), np.float32(0.9975515)), error=37.707462310791016
#       Orquestador actualizado: actor_loss=0.2916, critic_loss=0.0339
# 🔧 Entrenando controlador 0 con SP=399.7090148925781
#    Resultado: PID=(np.float32(4.016674), np.float32(0.07956054), np.float32(0.0020994663)), error=37.70592498779297
# 🔧 Entrenando controlador 1 con SP=102.75736236572266
#    Resultado: PID=(np.float32(100.0), np.float32(0.46272096), np.float32(0.015016551)), error=37.71039962768555
#       Orquestador actualizado: actor_loss=0.4055, critic_loss=0.0281
# 🔧 Entrenando controlador 0 con SP=385.375244140625
#    Resultado: PID=(np.float32(0.67574465), np.float32(0.75312614), np.float32(0.028078584)), error=37.709388732910156
# 🔧 Entrenando controlador 1 con SP=102.64063262939453
#    Resultado: PID=(np.float32(42.16545), np.float32(0.0031043277), np.float32(3.5623252e-05)), error=37.708099365234375
#       Orquestador actualizado: actor_loss=0.3103, critic_loss=0.0255
# 🔧 Entrenando controlador 0 con SP=380.8680725097656
#    Resultado: PID=(np.float32(0.014411526), np.float32(10.0), np.float32(9.407652e-11)), error=37.709896087646484
# 🔧 Entrenando controlador 1 con SP=103.0712661743164
#    Resultado: PID=(np.float32(0.01), np.float32(0.0001918365), np.float32(0.22271861)), error=37.718284606933594
#       Orquestador actualizado: actor_loss=0.3077, critic_loss=0.0357
# 🔧 Entrenando controlador 0 con SP=386.77850341796875
#    Resultado: PID=(np.float32(25.977905), np.float32(5.2183867), np.float32(0.040544685)), error=37.718528747558594
# 🔧 Entrenando controlador 1 con SP=102.97764587402344
#    Resultado: PID=(np.float32(0.03962713), np.float32(0.000104566505), np.float32(0.9576496)), error=37.70564270019531
#       Orquestador actualizado: actor_loss=0.4367, critic_loss=0.0301
# 🔧 Entrenando controlador 0 con SP=390.0869445800781
#    Resultado: PID=(np.float32(0.01), np.float32(0.14411525), np.float32(0.0009933849)), error=37.716068267822266
# 🔧 Entrenando controlador 1 con SP=103.10466766357422
#    Resultado: PID=(np.float32(0.01), np.float32(0.00073381665), np.float32(0.0030813278)), error=37.70551681518555
#       Orquestador actualizado: actor_loss=0.5010, critic_loss=0.0370
# 🔧 Entrenando controlador 0 con SP=401.55560302734375
#    Resultado: PID=(np.float32(0.02161729), np.float32(2.1868875e-05), np.float32(4.1038005e-05)), error=37.806888580322266
# 🔧 Entrenando controlador 1 con SP=102.34326171875
#    Resultado: PID=(np.float32(14.249677), np.float32(0.017332466), np.float32(0.0013183252)), error=37.71574783325195
#       Orquestador actualizado: actor_loss=0.0074, critic_loss=0.0230
# 🔧 Entrenando controlador 0 con SP=391.1410827636719
#    Resultado: PID=(np.float32(1.6814696), np.float32(0.012003318), np.float32(0.00073240296)), error=37.71258544921875
# 🔧 Entrenando controlador 1 con SP=103.00083923339844
#    Resultado: PID=(np.float32(2.5706718), np.float32(0.047828484), np.float32(0.011532713)), error=37.71103286743164
#       Orquestador actualizado: actor_loss=0.4739, critic_loss=0.0303
# 🔧 Entrenando controlador 0 con SP=388.5240783691406
#    Resultado: PID=(np.float32(0.9730726), np.float32(0.0412897), np.float32(0.004365461)), error=37.713680267333984
# 🔧 Entrenando controlador 1 con SP=103.0977783203125
#    Resultado: PID=(np.float32(0.51754457), np.float32(0.18245111), np.float32(5.1200004)), error=37.71260452270508
#       Orquestador actualizado: actor_loss=0.4436, critic_loss=0.0323
#
#  Run completado: still-sweep-2
#    Global reward: -0.15
#    Best SP: Tc=401.56, F=102.34
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_best_error</td><td>▁</td></tr><tr><td>avg_error</td><td>▁▁▁▁▂▂▂█▂▂</td></tr><tr><td>best_sp_f</td><td>▁</td></tr><tr><td>best_sp_tc</td><td>▁</td></tr><tr><td>cb_actual</td><td>▁▇▅▄█▇█▁▇█</td></tr><tr><td>cb_target</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>controller_0_Kd</td><td>▅█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>controller_0_Ki</td><td>▁▁▁▂█▅▁▁▁▁▁</td></tr><tr><td>controller_0_Kp</td><td>▁▁▂▁▁█▁▁▁▁▁</td></tr><tr><td>controller_0_error</td><td>▁▁▁▁▁▂▂█▂▂</td></tr><tr><td>+11</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_best_error</td><td>37.71516</td></tr><tr><td>avg_error</td><td>37.71314</td></tr><tr><td>best_sp_f</td><td>102.34326</td></tr><tr><td>best_sp_tc</td><td>401.5556</td></tr><tr><td>cb_actual</td><td>0.66828</td></tr><tr><td>cb_target</td><td>0.2</td></tr><tr><td>controller_0_Kd</td><td>4e-05</td></tr><tr><td>controller_0_Ki</td><td>2e-05</td></tr><tr><td>controller_0_Kp</td><td>0.02162</td></tr><tr><td>controller_0_error</td><td>37.71368</td></tr><tr><td>+11</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">still-sweep-2</strong> at: <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/zemuurg6' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa/runs/zemuurg6</a><br> View project at: <a href='https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa' target="_blank">https://wandb.ai/valeriaeskenazi-universidad-ort-uruguay/Tesis_maestr%C3%ADa</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251119_202750-zemuurg6/logs</code>
