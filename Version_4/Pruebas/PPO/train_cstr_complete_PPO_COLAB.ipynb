# %% [markdown]
# # Entrenamiento Completo - CSTR (CTRL + ORCH)
#
# **Pipeline completo**:
# 1. **Fase 1**: Entrenar agente CTRL para controlar Tc y F del CSTR
# 2. **Fase 2**: Entrenar agente ORCH para optimizar Cb usando el CTRL entrenado
#
# ---

# %% [markdown]
# ## 1. Imports y Setup

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path
import sys

# Agregar path del proyecto si es necesario
sys.path.append('../../')

from Environment.Simulation_Env.Reactor_CSTR import CSTRSimulator
from Environment.PIDControlEnv_simple import PIDControlEnv_Simple
from Environment.PIDControlEnv_complex import PIDControlEnv_Complex
from Agente.DQN.train_DQN import DQNTrainer
from Agente.DDPG.train_DDPG import DDPGTrainer
from Agente.Actor_Critic.train_AC import ACTrainer
from Agente.PPO.train_PPO import PPOTrainer
from Aux.Plots import SimplePlotter, print_summary

print(" Imports completados")
print(f"PyTorch version: {torch.__version__}")
print(f"Device disponible: {'CUDA' if torch.cuda.is_available() else 'CPU'}")
# Out:
#  Imports completados
# PyTorch version: 2.10.0+cu128
# Device disponible: CUDA

# %% [markdown]
# ---
# # FASE 1: Entrenar Agente CTRL
#
# **Objetivo**: Entrenar un agente que ajuste parámetros PID para controlar Tc y F.
#
# **Variables**:
# - **Manipulables**: Tc (290-450 K), F (99-105 m³/s)
# - **Setpoints**: Valores aleatorios dentro de los rangos
# - **Agente**: Aprende a ajustar (Kp, Ki, Kd) para cada variable

# %% [markdown]
# ## 2. Configuración CTRL

# %%
config_ctrl = {
    # ============ AMBIENTE ============
    'env_config': {
        'architecture': 'simple',
        'env_type': 'simulation',
        'max_time_detector': 30,
        'action_type': 'continuous',

        # 2 variables manipulables (Tc, F)
        'n_manipulable_vars': 2,
        'manipulable_ranges': [
            (300, 420),   # T del reactor [K]
            (99.5, 104),    # V del reactor [m³]
        ],

        # Los setpoints se generan aleatoriamente
        'manipulable_setpoints': None,  # Random

        'dt_usuario': 1.0,
        'max_steps': 100,

        'agent_controller_config': {
            'agent_type': 'continuous'
        },

        # Simulador CSTR
        'env_type_config': {
            'dt': 1.0,
            'control_limits': ((290, 450), (99.5, 104))
        },

        # Pesos de recompensa
        'reward_weights': {
            'error': 1.0,
            'tiempo': 0.001,
            'overshoot': 0.3,
            'energy': 0.001
        },
        'reward_dead_band': 0.02,

        # Límites PID
        'pid_limits': [
            (0.01, 50.0),
            (0.001, 1.0),
            (0.0, 1.0)
        ],
        'delta_percent_ctrl': 0.2,
    },

    # ============ AGENTE CTRL ============
    'agent_ctrl_config': {
        'algorithm': 'ppo',
        'state_dim': 10,       # 2 vars × 5 features
        'action_dim': 6,       # 2 vars × 3 params (Kp, Ki, Kd)
        'n_vars': 2,
        'action_type': 'continuous',
        'hidden_dims': (128, 64),
        'lr_actor': 0.0001,
        'lr_critic': 0.001,
        'gamma': 0.99,
        'tau': 0.005,
        'noise_sigma': 0.2,
        'noise_theta': 0.15,
        'batch_size': 64,
        'warmup_steps': 500,
        'buffer_size': 50000,
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'seed': 42
    },

    # ============ ENTRENAMIENTO ============
    'n_episodes': 1000,
    'max_steps_per_episode': 500,
    'eval_frequency': 50,
    'save_frequency': 9999,
    'log_frequency': 10,
    'checkpoint_dir': 'checkpoints/cstr_ctrl',
}

print("Configuración CTRL creada")
print(f"  Episodios: {config_ctrl['n_episodes']}")
print(f"  Device: {config_ctrl['agent_ctrl_config']['device']}")
# Out:
# Configuración CTRL creada
#   Episodios: 1000
#   Device: cuda

# %% [markdown]
# ## 3. Test Ambiente Simple

# %%
# Test ambiente
test_env = PIDControlEnv_Simple(config_ctrl['env_config'])
sim_cfg = config_ctrl['env_config']['env_type_config']
simulator = CSTRSimulator(**sim_cfg)
test_env.proceso.connect_external_process(simulator)
print('CSTR conectado al ambiente simple')

# Reset y step de prueba
obs, info = test_env.reset()
print(f"\nObservación shape: {obs.shape}")
print(f"  PVs iniciales: {test_env.manipulable_pvs}")
print(f"  Setpoints: {test_env.manipulable_setpoints}")

# Step aleatorio
action = test_env.action_space.sample()
obs, reward, done, truncated, info = test_env.step(action)
print(f"\nStep de prueba exitoso")
print(f"  Reward: {reward:.2f}")
# Out:
# CSTR conectado al ambiente simple
#
# Observación shape: (10,)
#   PVs iniciales: [327.0, 102.0]
#   Setpoints: [320.33403072344953, 103.89630943732077]
#
# Step de prueba exitoso
#   Reward: -2.26

# %% [markdown]
# ## 4. Entrenar CTRL

# %%
# Crear trainer CTRL
trainer_ctrl = PPOTrainer(config_ctrl)

# Conectar CSTR
sim_cfg = config_ctrl['env_config']['env_type_config']
simulator = CSTRSimulator(**sim_cfg)
trainer_ctrl.env.proceso.connect_external_process(simulator)
print('CSTR conectado al trainer CTRL')

print("\nEntrenando agente CTRL...\n")
print(trainer_ctrl.env.proceso.external_process)
print(trainer_ctrl.env.response_time_detectors.proceso.external_process)
trainer_ctrl.train()
print("\nEntrenamiento CTRL completado")
# Out:
# PPO Agent creado | role=ctrl | state=10 | action=6 | clip_ε=0.2 | epochs=10 | rollout=2048 | device=cuda
# CSTR conectado al trainer CTRL
#
# Entrenando agente CTRL...
#
# <Environment.Simulation_Env.Reactor_CSTR.CSTRSimulator object at 0x79634c11df10>
# <Environment.Simulation_Env.Reactor_CSTR.CSTRSimulator object at 0x79634c11df10>
#
# Episodio 0/1000
#   Reward: -373.45 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 101/2048 steps
#
# Episodio 10/1000
#   Reward: -676.57 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1111/2048 steps
#
# Episodio 20/1000
#   Reward: -1632.36 | Length: 101
#   Actor Loss: 0.0807 | Critic Loss: 5335.5430
#   Entropy: 9.0559 | Clip Fraction: 0.8738
#   Buffer: 73/2048 steps
#
# Episodio 30/1000
#   Reward: -1345.01 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1083/2048 steps
#
# Episodio 40/1000
#   Reward: -505.22 | Length: 101
#   Actor Loss: -0.0035 | Critic Loss: 22780.0979
#   Entropy: 9.2143 | Clip Fraction: 0.2611
#   Buffer: 45/2048 steps
#
# Episodio 50/1000
#   Reward: -1004.59 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1055/2048 steps
# Evaluación: Reward promedio = -1679.60
# PPO Agent guardado en: checkpoints/cstr_ctrl/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 60/1000
#   Reward: -2511.94 | Length: 101
#   Actor Loss: 0.0553 | Critic Loss: 25393.9572
#   Entropy: 9.0643 | Clip Fraction: 0.2265
#   Buffer: 17/2048 steps
#
# Episodio 70/1000
#   Reward: -867.87 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1027/2048 steps
#
# Episodio 80/1000
#   Reward: -63.72 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 2037/2048 steps
#
# Episodio 90/1000
#   Reward: -2558.87 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 999/2048 steps
#
# Episodio 100/1000
#   Reward: -28.96 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 2009/2048 steps
# Evaluación: Reward promedio = -3703.94
#
# Episodio 110/1000
#   Reward: -113.07 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 971/2048 steps
#
# Episodio 120/1000
#   Reward: -83.83 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1981/2048 steps
#
# Episodio 130/1000
#   Reward: -298.14 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 943/2048 steps
#
# Episodio 140/1000
#   Reward: -2722.36 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1953/2048 steps
#
# Episodio 150/1000
#   Reward: -1125.19 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 915/2048 steps
# Evaluación: Reward promedio = -2044.36
#
# Episodio 160/1000
#   Reward: -1861.47 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1925/2048 steps
#
# Episodio 170/1000
#   Reward: -741.31 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 887/2048 steps
#
# Episodio 180/1000
#   Reward: -1007.38 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1897/2048 steps
#
# Episodio 190/1000
#   Reward: -223.30 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 859/2048 steps
#
# Episodio 200/1000
#   Reward: -1774.84 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1869/2048 steps
# Evaluación: Reward promedio = -1417.71
# PPO Agent guardado en: checkpoints/cstr_ctrl/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 210/1000
#   Reward: -2909.36 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 831/2048 steps
#
# Episodio 220/1000
#   Reward: -1689.61 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1841/2048 steps
#
# Episodio 230/1000
#   Reward: -1875.80 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 803/2048 steps
#
# Episodio 240/1000
#   Reward: -1431.66 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1813/2048 steps
#
# Episodio 250/1000
#   Reward: -126.97 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 775/2048 steps
# Evaluación: Reward promedio = -1399.95
# PPO Agent guardado en: checkpoints/cstr_ctrl/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 260/1000
#   Reward: -393.83 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1785/2048 steps
#
# Episodio 270/1000
#   Reward: -281.68 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 747/2048 steps
#
# Episodio 280/1000
#   Reward: -130.69 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1757/2048 steps
#
# Episodio 290/1000
#   Reward: -537.92 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 719/2048 steps
#
# Episodio 300/1000
#   Reward: -634.52 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1729/2048 steps
# Evaluación: Reward promedio = -2526.40
#
# Episodio 310/1000
#   Reward: -112.54 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 691/2048 steps
#
# Episodio 320/1000
#   Reward: -304.55 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1701/2048 steps
#
# Episodio 330/1000
#   Reward: -25.06 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 663/2048 steps
#
# Episodio 340/1000
#   Reward: -99.75 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1673/2048 steps
#
# Episodio 350/1000
#   Reward: -403.26 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 635/2048 steps
# Evaluación: Reward promedio = -941.85
# PPO Agent guardado en: checkpoints/cstr_ctrl/agent_ctrl_best.pt
# Checkpoint guardado: best
#
# Episodio 360/1000
#   Reward: -1185.77 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1645/2048 steps
#
# Episodio 370/1000
#   Reward: -883.03 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 607/2048 steps
#
# Episodio 380/1000
#   Reward: -365.96 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1617/2048 steps
#
# Episodio 390/1000
#   Reward: -1661.23 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 579/2048 steps
#
# Episodio 400/1000
#   Reward: -587.36 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1589/2048 steps
# Evaluación: Reward promedio = -2836.02
#
# Episodio 410/1000
#   Reward: -411.21 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 551/2048 steps
#
# Episodio 420/1000
#   Reward: -2648.35 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1561/2048 steps
#
# Episodio 430/1000
#   Reward: -2339.41 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 523/2048 steps
#
# Episodio 440/1000
#   Reward: -16.05 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1533/2048 steps
#
# Episodio 450/1000
#   Reward: -689.87 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 495/2048 steps
# Evaluación: Reward promedio = -2372.54
#
# Episodio 460/1000
#   Reward: -24.46 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1505/2048 steps
#
# Episodio 470/1000
#   Reward: -25.56 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 467/2048 steps
#
# Episodio 480/1000
#   Reward: -2526.16 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1477/2048 steps
#
# Episodio 490/1000
#   Reward: -88.35 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 439/2048 steps
#
# Episodio 500/1000
#   Reward: -4.45 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1449/2048 steps
# Evaluación: Reward promedio = -2831.72
#
# Episodio 510/1000
#   Reward: -33.52 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 411/2048 steps
#
# Episodio 520/1000
#   Reward: -203.38 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1421/2048 steps
#
# Episodio 530/1000
#   Reward: -301.44 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 383/2048 steps
#
# Episodio 540/1000
#   Reward: -36.85 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1393/2048 steps
#
# Episodio 550/1000
#   Reward: -38.57 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 355/2048 steps
# Evaluación: Reward promedio = -2419.63
#
# Episodio 560/1000
#   Reward: -913.92 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1365/2048 steps
#
# Episodio 570/1000
#   Reward: -210.22 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 327/2048 steps
#
# Episodio 580/1000
#   Reward: -2107.52 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1337/2048 steps
#
# Episodio 590/1000
#   Reward: -2821.30 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 299/2048 steps
#
# Episodio 600/1000
#   Reward: -104.17 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1309/2048 steps
# Evaluación: Reward promedio = -1151.17
#
# Episodio 610/1000
#   Reward: -3121.86 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 271/2048 steps
#
# Episodio 620/1000
#   Reward: -78.81 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1281/2048 steps
#
# Episodio 630/1000
#   Reward: -1550.61 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 243/2048 steps
#
# Episodio 640/1000
#   Reward: -74.62 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1253/2048 steps
#
# Episodio 650/1000
#   Reward: -935.52 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 215/2048 steps
# Evaluación: Reward promedio = -1917.52
#
# Episodio 660/1000
#   Reward: -44.29 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1225/2048 steps
#
# Episodio 670/1000
#   Reward: -2459.73 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 187/2048 steps
#
# Episodio 680/1000
#   Reward: -39.86 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1197/2048 steps
#
# Episodio 690/1000
#   Reward: -24.12 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 159/2048 steps
#
# Episodio 700/1000
#   Reward: -101.27 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1169/2048 steps
# Evaluación: Reward promedio = -2981.13
#
# Episodio 710/1000
#   Reward: -151.58 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 131/2048 steps
#
# Episodio 720/1000
#   Reward: -710.32 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1141/2048 steps
#
# Episodio 730/1000
#   Reward: -219.48 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 103/2048 steps
#
# Episodio 740/1000
#   Reward: -23.01 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1113/2048 steps
#
# Episodio 750/1000
#   Reward: -50.10 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 10565.0810
#   Entropy: 11.5136 | Clip Fraction: 0.0000
#   Buffer: 75/2048 steps
# Evaluación: Reward promedio = -2491.58
#
# Episodio 760/1000
#   Reward: -1026.73 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1085/2048 steps
#
# Episodio 770/1000
#   Reward: -131.88 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 10161.6070
#   Entropy: 11.5136 | Clip Fraction: 0.0005
#   Buffer: 47/2048 steps
#
# Episodio 780/1000
#   Reward: -2257.21 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1057/2048 steps
#
# Episodio 790/1000
#   Reward: -422.45 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 10909.8930
#   Entropy: 11.5136 | Clip Fraction: 0.0000
#   Buffer: 19/2048 steps
#
# Episodio 800/1000
#   Reward: -46.72 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1029/2048 steps
# Evaluación: Reward promedio = -3297.98
#
# Episodio 810/1000
#   Reward: -110.65 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 2039/2048 steps
#
# Episodio 820/1000
#   Reward: -977.48 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1001/2048 steps
#
# Episodio 830/1000
#   Reward: -613.34 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 2011/2048 steps
#
# Episodio 840/1000
#   Reward: -277.38 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 973/2048 steps
#
# Episodio 850/1000
#   Reward: -107.58 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1983/2048 steps
# Evaluación: Reward promedio = -3411.98
#
# Episodio 860/1000
#   Reward: -43.56 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 945/2048 steps
#
# Episodio 870/1000
#   Reward: -2916.52 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1955/2048 steps
#
# Episodio 880/1000
#   Reward: -1358.95 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 917/2048 steps
#
# Episodio 890/1000
#   Reward: -175.75 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1927/2048 steps
#
# Episodio 900/1000
#   Reward: -144.20 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 889/2048 steps
# Evaluación: Reward promedio = -2856.31
#
# Episodio 910/1000
#   Reward: -282.82 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1899/2048 steps
#
# Episodio 920/1000
#   Reward: -719.15 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 861/2048 steps
#
# Episodio 930/1000
#   Reward: -614.40 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1871/2048 steps
#
# Episodio 940/1000
#   Reward: -109.44 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 833/2048 steps
#
# Episodio 950/1000
#   Reward: -35.07 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1843/2048 steps
# Evaluación: Reward promedio = -3240.28
#
# Episodio 960/1000
#   Reward: -5.32 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 805/2048 steps
#
# Episodio 970/1000
#   Reward: -915.22 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1815/2048 steps
#
# Episodio 980/1000
#   Reward: -3065.32 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 777/2048 steps
#
# Episodio 990/1000
#   Reward: -215.77 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1787/2048 steps
#
# Entrenamiento CTRL completado

# %% [markdown]
# ## 5. Visualizar Resultados CTRL

# %%
import importlib
import Aux.Plots  # o el path que uses para importarlo

importlib.reload(Aux.Plots)

# Volver a instanciar
from Aux.Plots import SimplePlotter, print_summary
plotter = SimplePlotter()

# %%
plotter = SimplePlotter()

# Resumen
print("\n" + "="*70)
print("RESULTADOS CTRL")
print_summary(
    episode_rewards=trainer_ctrl.episode_rewards,
    episode_energies=trainer_ctrl.episode_energies,
    episode_max_overshoots=trainer_ctrl.episode_max_overshoots,
    best_episode_idx=np.argmax(trainer_ctrl.episode_rewards)
)
print("="*70)

# Gráficos
plotter.plot_training_overview(
    episode_rewards=trainer_ctrl.episode_rewards,
    episode_energies=trainer_ctrl.episode_energies,
    episode_max_overshoots=trainer_ctrl.episode_max_overshoots,
    actor=trainer_ctrl.actor_losses,
    critic=trainer_ctrl.critic_losses,
    window=20
)

# Evolución de PIDs
plotter.plot_pid_evolution(
    kp_history=trainer_ctrl.kp_history,
    ki_history=trainer_ctrl.ki_history,
    kd_history=trainer_ctrl.kd_history,
    var_name="CSTR (Tc, F)"
)
# Out:
# ======================================================================
# RESULTADOS CTRL
# RESUMEN DE ENTRENAMIENTO
#
# Métrica                        Último       Promedio     Mejor
# Reward                            -2480.90     -587.58       -1.18
# Energy                         65448852.95 28632457.20        0.00
# Max Overshoot (%)                     0.00        0.00        0.00
#
#  Mejor episodio: #851 (Reward: -1.18)
# Mejora total: -564.3%
# Total episodios: 1000
# ======================================================================

# %% [markdown]
# ## 6. Guardar Checkpoint CTRL

# %%
# Guardar modelo CTRL
checkpoint_dir = Path(config_ctrl['checkpoint_dir'])
checkpoint_dir.mkdir(exist_ok=True, parents=True)

ctrl_checkpoint_path = checkpoint_dir / 'agent_ctrl_best.pt'
trainer_ctrl.agent_ctrl.save(str(ctrl_checkpoint_path))

print(f" Agente CTRL guardado en: {ctrl_checkpoint_path}")
print(f"\n Este checkpoint se usará para entrenar ORCH")
# Out:
# PPO Agent guardado en: checkpoints/cstr_ctrl/agent_ctrl_best.pt
#  Agente CTRL guardado en: checkpoints/cstr_ctrl/agent_ctrl_best.pt
#
#  Este checkpoint se usará para entrenar ORCH

# %% [markdown]
# ---
# #  FASE 2: Entrenar Agente ORCH
#
# **Objetivo**: Entrenar un agente orquestador que optimice la concentración Cb del reactor.
#
# **Arquitectura**:
# - **ORCH**: Observa Cb, decide setpoints para Tc y F
# - **CTRL** (pre-entrenado): Ajusta PIDs para alcanzar esos setpoints
# - **CSTR**: Procesa Tc y F → genera Cb

# %% [markdown]
# ## 7. Configuración ORCH

# %%
ctrl_checkpoint_path = Path('/Users/gonzalo/Documents/valeria/MASTER/TESIS/PID_Agent/Version_4/Pruebas/PPO/checkpoints/cstr_ctrl/agent_ctrl_best.pt')

# %%
config_orch = {
    # ============ AMBIENTE ============
    'env_config': {
        'architecture': 'jerarquica',
        'env_type': 'simulation',
        'max_time_detector': 30,
        'action_type': 'continuous',

        # Variables manipulables (controladas por CTRL)
        'n_manipulable_vars': 2,
        'manipulable_ranges': [
            (290, 450),   # T del reactor [K]
            (99, 105),    # V del reactor [m³]
        ],

        # Variable objetivo (optimizada por ORCH)
        'n_target_vars': 1,
        'target_ranges': [(0.0, 1.0)],           # Cb deseado
        'target_setpoints': [0.4],               # Objetivo: 0.4 mol/m³
        'target_working_ranges': [(0.0, 2.0)],   # Rango físico

        'dt_usuario': 1.0,
        'max_steps': 100,

        'agent_orchestrator_config': {
            'agent_type': 'continuous'
        },

        'env_type_config': {
            'dt': 1.0,
            'control_limits': ((290, 450), (99, 105))
        },

        'reward_weights': {
            'error': 2.0,
            'tiempo': 0.01,
            'overshoot': 0.5,
            'energy': 0.1
        },
        'reward_dead_band': 0.02,

        'pid_limits': [
            (0.01, 50.0),
            (0.001, 5.0),
            (0.001, 5.0)
        ],
        'delta_percent_ctrl': 0.2,
        'delta_percent_orch': 0.1,
    },

    # ============ AGENTE CTRL (Pre-entrenado) ============
    'ctrl_checkpoint_path': str(ctrl_checkpoint_path),  # Usa el checkpoint recién guardado
    'agent_ctrl_config': {
        'algorithm': 'ppo',
        'state_dim': 10,
        'action_dim': 6,
        'n_vars': 2,
        'action_type': 'continuous',
        'hidden_dims': (128, 64),
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    },

    # ============ AGENTE ORCH (A entrenar) ============
    'agent_orch_config': {
        'state_dim': 5,
        'action_dim': 3,
        'n_vars': 2,
        'hidden_dims': (64, 32),
        'lr_actor': 0.0001,
        'lr_critic': 0.001,
        'entropy_coef': 0.01,
        'warmup_steps': 500,
        'batch_size': 32,
        'target_update_freq': 100,
        'buffer_type': 'simple',
        'buffer_size': 50000,
        'device': 'cuda' if torch.cuda.is_available() else 'cpu',
        'seed': 42
    },

    # ============ ENTRENAMIENTO ============
    'n_episodes': 100,
    'max_steps_per_episode': 500,
    'eval_frequency': 50,
    'save_frequency': 9999,
    'log_frequency': 10,
    'checkpoint_dir': 'checkpoints/cstr_orch',
}

print(" Configuración ORCH creada")
print(f"  Checkpoint CTRL: {config_orch['ctrl_checkpoint_path']}")
print(f"  Episodios: {config_orch['n_episodes']}")
# Out:
#  Configuración ORCH creada
#   Checkpoint CTRL: checkpoints/cstr_ctrl/agent_ctrl_best.pt
#   Episodios: 100

# %% [markdown]
# ## 8. Test Ambiente Complejo

# %%
# Test ambiente
test_env_orch = PIDControlEnv_Complex(config_orch['env_config'])
sim_cfg = config_orch['env_config']['env_type_config']
simulator = CSTRSimulator(**sim_cfg)
test_env_orch.proceso.connect_external_process(simulator)
print(' CSTR conectado al ambiente complejo')

obs, info = test_env_orch.reset()
print(f"\nObservación:")
print(f"  ORCH obs shape: {obs['orch'].shape}")
print(f"  CTRL obs shape: {obs['ctrl'].shape}")
print(f"  Cb actual: {info['target_pvs'][0]:.4f} mol/m³")
print(f"  Cb objetivo: 0.4 mol/m³")
# Out:
#  CSTR conectado al ambiente complejo
#
# Observación:
#   ORCH obs shape: (5,)
#   CTRL obs shape: (10,)
#   Cb actual: 1.7327 mol/m³
#   Cb objetivo: 0.4 mol/m³

# %% [markdown]
# ## 9. Entrenar ORCH

# %%
# Crear trainer ORCH
trainer_orch = PPOTrainer(config_orch)

# Conectar CSTR
sim_cfg = config_orch['env_config']['env_type_config']
simulator = CSTRSimulator(**sim_cfg)
trainer_orch.env.proceso.connect_external_process(simulator)
print(' CSTR conectado al trainer ORCH')

print("\n Entrenando agente ORCH...\n")
trainer_orch.train()
print("\nEntrenamiento ORCH completado")
# Out:
# Cargando agente CTRL pre-entrenado desde: checkpoints/cstr_ctrl/agent_ctrl_best.pt
# PPO Agent creado | role=ctrl | state=10 | action=6 | clip_ε=0.2 | epochs=10 | rollout=2048 | device=cuda
# PPO Agent cargado desde: checkpoints/cstr_ctrl/agent_ctrl_best.pt
# PPO Agent creado | role=orch | state=5 | action=3 | clip_ε=0.2 | epochs=10 | rollout=2048 | device=cuda
#  CSTR conectado al trainer ORCH
#
#  Entrenando agente ORCH...
#
#
# Episodio 0/100
#   Reward: -20.03 | Length: 39
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 39/2048 steps
#
# Episodio 10/100
#   Reward: -41.81 | Length: 40
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 584/2048 steps
#
# Episodio 20/100
#   Reward: -112.78 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1456/2048 steps
#
# Episodio 30/100
#   Reward: -41.75 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 214/2048 steps
#
# Episodio 40/100
#   Reward: -154.19 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1161/2048 steps
#
# Episodio 50/100
#   Reward: -108.80 | Length: 84
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1929/2048 steps
# Evaluación: Reward promedio = -100.72
# PPO Agent guardado en: checkpoints/cstr_orch/agent_ctrl_best.pt
# PPO Agent guardado en: checkpoints/cstr_orch/agent_orch_best.pt
# Checkpoint guardado: best
#
# Episodio 60/100
#   Reward: -124.03 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 756/2048 steps
#
# Episodio 70/100
#   Reward: -104.96 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 1517/2048 steps
#
# Episodio 80/100
#   Reward: -10.66 | Length: 19
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 26/2048 steps
#
# Episodio 90/100
#   Reward: -115.47 | Length: 101
#   Actor Loss: 0.0000 | Critic Loss: 0.0000
#   Entropy: 0.0000 | Clip Fraction: 0.0000
#   Buffer: 849/2048 steps
#
# Entrenamiento ORCH completado

# %% [markdown]
# ## 10. Visualizar Resultados ORCH

# %%
from Aux.Plots import SimplePlotter, print_summary

plotter = SimplePlotter()

# %%
# Resumen
print("\n" + "="*70)
print(" RESULTADOS ORCH")
print_summary(
    episode_rewards=trainer_orch.episode_rewards,
    episode_energies=trainer_orch.episode_energies,
    episode_max_overshoots=trainer_orch.episode_max_overshoots,
    best_episode_idx=np.argmax(trainer_orch.episode_rewards)
)
print("="*70)

# Gráficos
plotter.plot_training_overview(
    episode_rewards=trainer_orch.episode_rewards,
    episode_energies=trainer_orch.episode_energies,
    episode_max_overshoots=trainer_orch.episode_max_overshoots,
    actor=trainer_orch.actor_losses,
    critic=trainer_orch.critic_losses,
    window=20
)
# Out:
# ======================================================================
#  RESULTADOS ORCH
# RESUMEN DE ENTRENAMIENTO
#
# Métrica                        Último       Promedio     Mejor
# Reward                              -56.32      -92.06       -1.40
# Energy                                0.00        0.00        0.00
# Max Overshoot (%)                     0.00        0.00        0.00
#
#  Mejor episodio: #93 (Reward: -1.40)
# Mejora total: -181.1%
# Total episodios: 100
# ======================================================================

# %% [markdown]
# ## 11. Evaluación - Sistema Completo en Acción

# %%
# Reset
obs, info = trainer_orch.env.reset()
print(f" Condiciones iniciales:")
print(f"  Cb: {info['target_pvs'][0]:.4f} mol/m³ (objetivo: 0.4)")
print(f"  Tc: {info['manipulable_pvs'][0]:.2f} K")
print(f"  F: {info['manipulable_pvs'][1]:.2f} m³/s")

# Ejecutar episodio
cb_traj = [info['target_pvs'][0]]
tc_traj = [info['manipulable_pvs'][0]]
f_traj = [info['manipulable_pvs'][1]]
rewards_traj = []

done = False
step = 0
max_steps = 500

print(f"\n Ejecutando episodio...")
print(f"{'Step':<6} {'Cb':<10} {'Tc':<10} {'F':<10} {'Reward':<10}")
print("-" * 50)

while not done and step < max_steps:
    action = trainer_orch.agent_orch.select_action(obs['orch'], training=False)
    obs, reward, terminated, truncated, info = trainer_orch.env.step(action)
    done = terminated or truncated

    cb_traj.append(info['target_pvs'][0])
    tc_traj.append(info['manipulable_pvs'][0])
    f_traj.append(info['manipulable_pvs'][1])
    rewards_traj.append(reward)

    print(f"{step:<6} {info['target_pvs'][0]:<10.4f} {info['manipulable_pvs'][0]:<10.2f} "
          f"{info['manipulable_pvs'][1]:<10.2f} {reward:<10.2f}")

    step += 1

print("-" * 50)
print(f"\n Episodio completado")
print(f"  Cb final: {cb_traj[-1]:.4f} mol/m³")
print(f"  Error final: {abs(cb_traj[-1] - 0.4):.4f}")
print(f"  Reward total: {sum(rewards_traj):.2f}")
# Out:
#  Condiciones iniciales:
#   Cb: 1.6763 mol/m³ (objetivo: 0.4)
#   Tc: 327.00 K
#   F: 102.00 m³/s
#
#  Ejecutando episodio...
# Step   Cb         Tc         F          Reward
# --------------------------------------------------
# 0      0.4129     427.54     105.00     -0.38
# 1      0.5095     395.59     105.00     -0.20
# 2      0.5095     395.59     105.00     -0.07
# 3      0.5095     395.59     105.00     -0.07
# 4      0.5095     395.59     105.00     -0.07
# 5      0.5095     395.59     105.00     -0.07
# 6      0.5095     395.59     105.00     -0.07
# 7      0.5095     395.59     105.00     -0.07
# 8      0.5095     395.59     105.00     -0.07
# 9      0.5095     395.59     105.00     -0.07
# 10     0.5095     395.59     105.00     -0.07
# 11     0.5095     395.59     105.00     -0.07
# 12     0.5095     395.59     105.00     -0.07
# 13     0.5095     395.59     105.00     -0.07
# 14     0.5095     395.59     105.00     -0.07
# 15     0.5095     395.59     105.00     -0.07
# 16     0.5095     395.59     105.00     -0.07
# 17     0.5095     395.59     105.00     -0.07
# 18     0.5095     395.59     105.00     -0.07
# 19     0.5095     395.59     105.00     -0.07
# 20     0.5095     395.59     105.00     -0.07
# 21     0.5095     395.59     105.00     -0.07
# 22     0.5095     395.59     105.00     -0.07
# 23     0.5095     395.59     105.00     -0.07
# 24     0.5095     395.59     105.00     -0.07
# 25     0.5095     395.59     105.00     -0.07
# 26     0.5095     395.59     105.00     -0.07
# 27     0.5095     395.59     105.00     -0.07
# 28     0.5095     395.59     105.00     -0.07
# 29     0.5095     395.59     105.00     -0.07
# 30     0.5095     395.59     105.00     -0.07
# 31     0.5095     395.59     105.00     -0.07
# 32     0.5095     395.59     105.00     -0.07
# 33     0.5095     395.59     105.00     -0.07
# 34     0.5095     395.59     105.00     -0.07
# 35     0.5095     395.59     105.00     -0.07
# 36     0.5095     395.59     105.00     -0.07
# 37     0.5095     395.59     105.00     -0.07
# 38     0.5095     395.59     105.00     -0.07
# 39     0.5163     409.80     105.00     -0.22
# 40     0.7377     421.83     105.00     -0.68
# 41     0.8489     416.11     105.00     -0.94
# 42     0.6646     424.45     105.00     -0.53
# 43     0.5891     327.79     105.00     -0.44
# 44     0.5588     393.66     105.00     -0.31
# 45     0.7550     381.93     105.00     -0.70
# 46     0.7085     423.28     105.00     -0.65
# 47     0.3728     315.81     103.99     -0.36
# 48     0.6630     395.32     105.00     -0.62
# 49     0.6630     395.32     105.00     -0.38
# 50     0.6630     395.32     105.00     -0.38
# 51     0.6630     395.32     105.00     -0.38
# 52     0.6630     395.32     105.00     -0.38
# 53     0.7888     421.88     104.01     -0.79
# 54     0.7502     356.39     105.00     -0.79
# 55     0.7292     415.19     105.00     -0.64
# 56     0.5307     427.16     105.00     -0.25
# 57     0.7692     421.16     105.00     -0.74
# 58     0.6205     330.24     105.00     -0.52
# 59     0.5034     366.53     105.00     -0.20
# 60     0.4472     427.63     105.00     -0.20
# 61     0.7749     421.74     104.01     -0.76
# 62     0.6401     394.39     105.00     -0.57
# 63     0.6401     394.39     105.00     -0.33
# 64     0.6401     394.39     105.00     -0.33
# 65     0.6401     394.39     105.00     -0.33
# 66     0.6401     394.39     105.00     -0.33
# 67     0.6401     394.39     105.00     -0.33
# 68     0.6401     394.39     105.00     -0.33
# 69     0.6401     394.39     105.00     -0.33
# 70     0.6401     394.39     105.00     -0.33
# 71     0.6401     394.39     105.00     -0.33
# 72     0.6401     394.39     105.00     -0.33
# 73     0.6401     394.39     105.00     -0.33
# 74     0.6401     394.39     105.00     -0.33
# 75     0.6401     394.39     105.00     -0.33
# 76     0.6401     394.39     105.00     -0.33
# 77     0.6401     394.39     105.00     -0.33
# 78     0.6401     394.39     105.00     -0.33
# 79     0.6401     394.39     105.00     -0.33
# 80     0.4843     427.46     105.00     -0.17
# 81     0.8489     408.02     105.00     -0.98
# 82     0.8244     412.50     105.00     -0.83
# 83     0.7986     416.71     105.00     -0.78
# 84     0.5356     427.40     105.00     -0.28
# 85     0.8444     408.05     105.00     -0.98
# 86     0.5170     426.74     105.00     -0.22
# 87     0.8041     416.87     105.00     -0.80
# 88     0.4884     338.48     105.00     -0.17
# 89     0.5438     425.67     105.00     -0.38
# 90     0.7530     397.79     105.00     -0.69
# 91     0.8029     416.77     105.00     -0.80
# 92     0.7655     421.59     105.00     -0.73
# 93     0.8487     408.12     105.00     -0.98
# 94     0.4009     428.32     105.00     -0.28
# 95     0.4939     321.94     105.00     -0.18
# 96     0.3964     316.44     105.00     -0.30
# 97     0.5860     393.64     105.00     -0.45
# 98     0.5836     392.92     105.00     -0.35
# 99     0.5836     392.92     105.00     -0.22
# 100    0.5836     392.92     105.00     -0.26
# --------------------------------------------------
#
#  Episodio completado
#   Cb final: 0.5836 mol/m³
#   Error final: 0.1836
#   Reward total: -32.04

# %% [markdown]
# ## 12. Visualización Final

# %%
fig, axes = plt.subplots(3, 1, figsize=(14, 10))
steps = np.arange(len(cb_traj))

# Cb
ax = axes[0]
ax.plot(steps, cb_traj, label='Cb', color='#2E86AB', linewidth=2.5, marker='o', markersize=4)
ax.axhline(y=0.4, label='Objetivo', color='#C73E1D', linestyle='--', linewidth=2)
ax.fill_between(steps, 0.392, 0.408, alpha=0.2, color='#06A77D', label='±2%')
ax.set_ylabel('Cb [mol/m³]', fontsize=12)
ax.set_title('🎯 Concentración de B (Variable Objetivo)', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(True, alpha=0.3)

# Tc y F
ax = axes[1]
ax.plot(steps, tc_traj, label='Tc', color='#F18F01', linewidth=2, marker='s', markersize=3)
ax.set_ylabel('Tc [K]', fontsize=12, color='#F18F01')
ax.tick_params(axis='y', labelcolor='#F18F01')
ax.legend(loc='upper left')
ax.grid(True, alpha=0.3)

ax2 = ax.twinx()
ax2.plot(steps, f_traj, label='F', color='#06A77D', linewidth=2, marker='^', markersize=3)
ax2.set_ylabel('F [m³/s]', fontsize=12, color='#06A77D')
ax2.tick_params(axis='y', labelcolor='#06A77D')
ax2.legend(loc='upper right')
ax.set_title('🔧 Variables Manipuladas (Decididas por ORCH → Controladas por CTRL)',
             fontsize=14, fontweight='bold')

# Rewards
ax = axes[2]
ax.plot(range(len(rewards_traj)), rewards_traj, color='#C73E1D', linewidth=2, marker='o', markersize=4)
ax.axhline(y=0, color='black', linestyle='--', alpha=0.5)
ax.set_xlabel('Step', fontsize=12)
ax.set_ylabel('Reward', fontsize=12)
ax.set_title('💰 Recompensa', fontsize=14, fontweight='bold')
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1174/981889224.py:39: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) Liberation Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1174/981889224.py:39: UserWarning: Glyph 128295 (\N{WRENCH}) missing from font(s) Liberation Sans.
#   plt.tight_layout()
# /tmp/ipython-input-1174/981889224.py:39: UserWarning: Glyph 128176 (\N{MONEY BAG}) missing from font(s) Liberation Sans.
#   plt.tight_layout()

# %% [markdown]
# ## 13. Guardar Modelos Finales

# %%
# Guardar ORCH
orch_dir = Path(config_orch['checkpoint_dir'])
orch_dir.mkdir(exist_ok=True, parents=True)
orch_path = orch_dir / 'agent_orch_final.pt'
trainer_orch.agent_orch.save(str(orch_path))

print(f"Modelos guardados:")
print(f"  CTRL: {ctrl_checkpoint_path}")
print(f"  ORCH: {orch_path}")
# Out:
# PPO Agent guardado en: checkpoints/cstr_orch/agent_orch_final.pt
# Modelos guardados:
#   CTRL: checkpoints/cstr_ctrl/agent_ctrl_best.pt
#   ORCH: checkpoints/cstr_orch/agent_orch_final.pt
